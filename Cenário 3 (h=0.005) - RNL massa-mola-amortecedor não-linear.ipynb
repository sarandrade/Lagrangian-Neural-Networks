# %% [markdown]
# ## **RNL - Modelo Massa-Mola-Amortecedor Não Linear**

# %% [markdown]
# ## **Step 1: Imports**

# %%
from jax.experimental.ode import odeint
from jax.experimental import optimizers
from jax.experimental import stax
from jax.lib import xla_bridge
import jax.numpy as jnp
import jax

# Verificando se a GPU está sendo usada
print(xla_bridge.get_backend().platform)
# Out:
# /usr/local/lib/python3.7/dist-packages/jax/experimental/optimizers.py:30: FutureWarning: jax.experimental.optimizers is deprecated, import jax.example_libraries.optimizers instead
#   FutureWarning)
# /usr/local/lib/python3.7/dist-packages/jax/experimental/stax.py:30: FutureWarning: jax.experimental.stax is deprecated, import jax.example_libraries.stax instead
#   FutureWarning)
# gpu

# %%
from functools import partial # reduces arguments to function by making some subset implicit
import pandas as pd
import numpy as np
import io

# visualization
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Step 2: Massa-Mola-Amortecedor**
# The Lagrangian of this system is
#
# $$
# \begin{align}
# L = T - U
# \end{align}
# $$
# $$
# \begin{align}
# L = \frac{1}{2}m \dot{x}^2 - (\frac{1}{b_2 + 1} b_1 (x_o + x)^{b_2+1} - m g x - \frac{1}{b_2 + 1} b_1 x_o^{b_2+1})
# \end{align}
# $$
# $$
# \begin{align}
# x_o = (\frac{m g}{b_1})^{\frac{1}{b_2}}
# \end{align}
# $$
# $$
# \begin{align}
# m = 150 g = 0,15 kg
# \end{align}
# $$
# $$
# \begin{align}
# b_1 = 161,9783
# \end{align}
# $$
# $$
# \begin{align}
# b_2 = 0,9099
# \end{align}
# $$
# $$
# \begin{align}
# g = 9.8  m/s^2
# \end{align}
# $$
#
# <img src="https://www.researchgate.net/publication/321688991/figure/fig1/AS:569465399189504@1512782539716/Figura-1-Sistema-massa-mola-vertical-em-equilibrio.png">

# %%
def calculate_xo(m, b1, b2, g):
  xo = ((m * g) / b1) ** (1/b2)

  return xo

# %%
def lagrangian(q, q_dot, m=0.15, b1=161.9783, b2=1.9099, g=9.8):
  x, = q  
  v, = q_dot
  xo = calculate_xo(m=m, b1=b1, b2=b2, g=g)
  
  # kinetic energy (T)
  T = 0.5 * m * (v) ** 2

  # potential energy (V)
  V = (b1 * (xo + x) ** (b2 + 1))/(b2 + 1) - m * g * x - (b1 * xo ** (b2 + 1))/(b2 + 1)
 
  return T - V

# %% [markdown]
# The analytical of this system is
#
# \begin{align}
# a = \frac{- b_1(x_0 + x)^{b_2} - c\dot{x}}{m} + g
# \end{align}
# \begin{align}
# c = 1.2732
# \end{align}
#
#
# <img src="https://www.researchgate.net/profile/Marcelo-H-Belonsi/publication/300728274/figure/fig3/AS:355514522325005@1461772675608/Figura-5-Sistema-Massa-Mola-Amortecedor.png">

# %%
def f_analytical(state, t=0, m=0.15, b1=161.9783, b2=1.9099, c=1.2732, g=9.8):
  x, v = state
  xo = calculate_xo(m=m, b1=b1, b2=b2, g=g)

  a = (- b1 * (xo + x) ** b2 - c * v)/m + g

  return jnp.stack([v, a])

# %% [markdown]
# ## **Step 3: Obtain dynamics from the Lagrangian**
# To obtain the dynamics through numerical integration, and to do this we'll need an expression for $\ddot q$. Let's begin with the E-L constraint and try to solve for $\ddot q$.
#
# $$
# \begin{align}
# \frac{d}{dt} \frac{\partial \mathcal{L}}{\partial \dot q_j} - \frac{\partial \mathcal{L}}{\partial q_j} & = - c\dot q & \text{write down the Euler-Lagrange equation} \quad (1)\\
# \frac{d}{dt} \nabla_{\dot q} \mathcal{L} - \nabla_{q} \mathcal{L} & = - c\dot q & \text{switch to vector notation} \quad (2)\\
# (\nabla_{\dot q}\nabla_{\dot q}^{\top}\mathcal{L})\ddot q + (\nabla_{q}\nabla_{\dot q}^{\top}\mathcal{L}) \dot q - \nabla_q \mathcal{L} & = - c\dot q & \text{expand the time derivative }\frac{d}{dt} \quad (3)\\
# \ddot q &= (\nabla_{\dot q}\nabla_{\dot q}^{\top}\mathcal{L})^{-1}[\nabla_q \mathcal{L} - (\nabla_{q}\nabla_{\dot q}^{\top}\mathcal{L})\dot q - c\dot q ] & \text{use a matrix inverse to solve for } \ddot q \quad (4)\\
# \end{align}
# $$
#
# **Implementation.** If you look closely at Equation 4, you may notice that it involves both the Hessian and the gradient of a neural network during the forward pass of the LNN. This is not a trivial operation, but modern automatic differentiation makes things surprisingly smooth. Written in JAX, Equation 4 is just a few lines of code
# ```
# q_tt = jnp.linalg.pinv(jax.hessian(lagrangian, 1)(q, q_t)) @ (
#     jax.grad(lagrangian, 0)(q, q_t)
#     - jax.jacobian(jax.jacobian(lagrangian, 1), 0)(q, q_t) @ q_t
#     - c * q_t)
# ```

# %%
def equation_of_motion(lagrangian, state, t=None, c=1.2732):
  q, q_t = jnp.split(state, 2)

  q_tt = (jnp.linalg.pinv(jax.hessian(lagrangian, 1)(q, q_t)) @ (
  jax.grad(lagrangian, 0)(q, q_t)
  - jax.jacobian(jax.jacobian(lagrangian, 1), 0)(q, q_t) @ q_t - c * q_t))
  
  return jnp.concatenate([q_t, q_tt])


def solve_lagrangian(lagrangian, initial_state, **kwargs):
  # We currently run odeint on CPUs only, because its cost is dominated by
  # control flow, which is slow on GPUs.
  @partial(jax.jit, backend='cpu')
  def f(initial_state):
    return odeint(partial(equation_of_motion, lagrangian),
                  initial_state, **kwargs)
  return f(initial_state)


@partial(jax.jit, backend='cpu')
def solve_autograd(initial_state, times, m=0.15, b1=161.9783, b2=1.9099, g=9.8):
  L = partial(lagrangian, m=m, b1=b1, b2=b2, g=g)
  solved = solve_lagrangian(L, initial_state, t=times, rtol=1e-10, atol=1e-10)
  return solved


@partial(jax.jit, backend='cpu')
def solve_analytical(initial_state, times):
  solved = odeint(f_analytical, initial_state, t=times, rtol=1e-10, atol=1e-10)
  return solved


def normalize_dp(state):
  # wrap generalized coordinates to [-pi, pi]
  return jnp.concatenate([(state[:1] + np.pi) % (2 * np.pi) - np.pi, state[1:]])


def rk4_step(f, x, t, h):
  # one step of runge-kutta integration
  k1 = h * f(x, t)
  k2 = h * f(x + k1/2, t + h/2)
  k3 = h * f(x + k2/2, t + h/2)
  k4 = h * f(x + k3, t + h)
  return x + 1/6 * (k1 + 2 * k2 + 2 * k3 + k4)

# %%
# choose an initial state
N = 10000
t = np.arange(start=0, stop=5, step=50/N, dtype=np.float32)
x0 = np.array([0.012, 0], dtype=np.float32)

# %%
# compute dynamics analytically
# %time x_analytical = jax.device_get(solve_analytical(x0, t))
# Out:
# CPU times: user 735 ms, sys: 34.7 ms, total: 769 ms
# Wall time: 1.25 s

# %%
# compute dynamics via autograd / the rewritten E-L equation
# %time x_autograd = jax.device_get(solve_autograd(x0, t))
# Out:
# CPU times: user 1.09 s, sys: 22.6 ms, total: 1.11 s
# Wall time: 1.13 s

# %% [markdown]
# ### Plot a comparison

# %%
plt.figure(figsize=[14,4], dpi=120)
plt.subplot(1,2,1)
plt.title("Deslocamento calculado pela 2ª lei de Newton")
plt.xlabel("Tempo") ; plt.ylabel("Deslocamento")
plt.plot(t, x_analytical[:, 0], 'g-', label=r'deslocamento') ; plt.xlim(-0.1, 5)
plt.subplot(1,2,2)
plt.title("Deslocamento calculado por Euler-Lagrange")
plt.xlabel("Tempo") ; plt.ylabel("Deslocamento")
plt.plot(t, x_autograd[:, 0], 'c-', label=r'deslocamento') ; plt.xlim(-0.1, 5)

plt.figure(figsize=[14,4], dpi=120)
plt.subplot(1,2,1)
plt.title("Velocidade calculada pela 2ª lei de Newton")
plt.xlabel("Tempo") ; plt.ylabel("Velocidade")
plt.plot(t, x_analytical[:, 1], 'g-', label=r'velocidade') ; plt.xlim(-0.1, 5)
plt.subplot(1,2,2)
plt.title("Velocidade calculada por Euler-Lagrange")
plt.xlabel("Tempo") ; plt.ylabel("Velocidade")
plt.plot(t, x_autograd[:, 1], 'c-', label=r'velocidade') ; plt.xlim(-0.1, 5)
# Out:
# (-0.1, 5.0)

# %%
plt.figure(figsize=[14,4], dpi=120)
plt.subplot(1,2,1)
plt.title("Deslocamento calculado pela 2ª lei de Newton")
plt.xlabel("Tempo") ; plt.ylabel("Deslocamento")
plt.plot(t, x_analytical[:, 0], 'g-', label=r'deslocamento') ; plt.xlim(-0.1, 5)
plt.subplot(1,2,2)
plt.title("Velocidade calculada pela 2ª lei de Newton")
plt.xlabel("Tempo") ; plt.ylabel("Velocidade")
plt.plot(t, x_analytical[:, 1], 'c-', label=r'velocidade') ; plt.xlim(-0.1, 5)
plt.savefig('cen3-new-h5.png')

plt.figure(figsize=[14,4], dpi=120)
plt.subplot(1,2,1)
plt.title("Deslocamento calculado por Euler-Lagrange")
plt.xlabel("Tempo") ; plt.ylabel("Deslocamento")
plt.plot(t, x_autograd[:, 0], 'g-', label=r'deslocamento') ; plt.xlim(-0.1, 5)
plt.subplot(1,2,2)
plt.title("Velocidade calculada por Euler-Lagrange")
plt.xlabel("Tempo") ; plt.ylabel("Velocidade")
plt.plot(t, x_autograd[:, 1], 'c-', label=r'velocidade') ; plt.xlim(-0.1, 5)
plt.savefig('cen3-lag-h5.png')

# %% [markdown]
# ## **Step 5: Generate training data**
# Let's generate some training data by using the analytical method to sample mass-spring-damper dynamics.

# %%
time_step = 0.005
analytical_step = jax.jit(jax.vmap(partial(rk4_step, f_analytical, t=0.0, h=time_step)))

N = 10000
x0 = np.array([0.012, 0], dtype=np.float32)

# Train data
t = np.arange(start=0, stop=10, step=50/N, dtype=np.float32) # time steps 0 to N
# %time x_train = jax.device_get(solve_analytical(x0, t)) # dynamics for first N time steps
# %time xt_train = jax.device_get(jax.vmap(f_analytical)(x_train)) # time derivatives of each state
# %time y_train = jax.device_get(analytical_step(x_train)) # analytical next step

# Test data
t_test = np.arange(start=10, stop=20, step=50/N, dtype=np.float32) # time steps N to 2N
# %time x_test = jax.device_get(solve_analytical(x0, t_test)) # dynamics for next N time steps
# %time xt_test = jax.device_get(jax.vmap(f_analytical)(x_test)) # time derivatives of each state
# %time y_test = jax.device_get(analytical_step(x_test)) # analytical next step
# Out:
# CPU times: user 1.02 s, sys: 17.5 ms, total: 1.04 s
# Wall time: 1.52 s
# CPU times: user 443 ms, sys: 192 ms, total: 635 ms
# Wall time: 2.18 s
# CPU times: user 405 ms, sys: 12.5 ms, total: 417 ms
# Wall time: 645 ms
# CPU times: user 2.24 ms, sys: 118 µs, total: 2.36 ms
# Wall time: 1.62 ms
# CPU times: user 15.7 ms, sys: 984 µs, total: 16.7 ms
# Wall time: 15.9 ms
# CPU times: user 0 ns, sys: 773 µs, total: 773 µs
# Wall time: 746 µs

# %% [markdown]
# ### Visualize train and test data

# %%
# preprocess
train_vis = jax.vmap(normalize_dp)(x_train)
test_vis = jax.vmap(normalize_dp)(x_test)

# plot train data
SCALE = 80 ; WIDTH = 0.006
plt.figure(figsize=[8,4], dpi=120)
plt.plot(t, train_vis[:, 0], 'b-', label='$deslocamento$')
plt.plot(t, train_vis[:, 1], 'g-', label='$velocidade$')
plt.title("Dados de treino") ; plt.xlabel('Tempo') ; plt.ylabel('Estado')
plt.legend(fontsize=6)

# %%
# plot test data
SCALE = 80 ; WIDTH = 0.006
plt.figure(figsize=[8,4], dpi=120)
plt.plot(t_test, test_vis[:, 0], 'b-', label='$deslocamento$')
plt.plot(t_test, test_vis[:, 1], 'g-', label='$velocidade$')
plt.title("Dados de teste") ; plt.xlabel('Tempo') ; plt.ylabel('Estado')
plt.legend(fontsize=6)

# %% [markdown]
# ## **Step 6: Build a Lagrangian Neural Network**
# This section presents a bare-bones approach to approximating the Lagrangian with a neural network
#
# ### i) Build model and define the loss

# %%
# Replace the lagrangian with a parameteric model
def learned_lagrangian(params):
  def lagrangian(q, q_t):
    assert q.shape == (1,)
    state = normalize_dp(jnp.concatenate([q, q_t]))

    return jnp.squeeze(nn_forward_fn(params, state), axis=-1)

  return lagrangian

# Define the loss of the model (MSE between predicted q, \dot q and targets)
@jax.jit
def loss(params, batch, time_step=None):
  state, targets = batch
  if time_step is not None:
    f = partial(equation_of_motion, learned_lagrangian(params))
    preds = jax.vmap(partial(rk4_step, f, t=0.0, h=time_step))(state)
  else:
    preds = jax.vmap(partial(equation_of_motion, learned_lagrangian(params)))(state)
    
  return jnp.mean((preds - targets) ** 2)

# Build a neural network model
init_random_params, nn_forward_fn = stax.serial(
    stax.Dense(128),
    stax.Softplus,
    stax.Dense(128),
    stax.Softplus,
    stax.Dense(1),
)

# %% [markdown]
# ### ii) Define optimization and data

# %%
@jax.jit
def update_timestep(i, opt_state, batch):
  params = get_params(opt_state)
  return opt_update(i, jax.grad(loss)(params, batch, time_step), opt_state)

@jax.jit
def update_derivative(i, opt_state, batch):
  params = get_params(opt_state)
  return opt_update(i, jax.grad(loss)(params, batch, None), opt_state)

x_train = jax.device_put(jax.vmap(normalize_dp)(x_train))
x_test = jax.device_put(jax.vmap(normalize_dp)(x_test))

# %% [markdown]
# ### iii) Train the model

# %%
# %%time

rng = jax.random.PRNGKey(0)
_, init_params = init_random_params(rng, (-1, 2))

# numbers in comments denote stephan's settings
batch_size = 100
test_every = 10
num_batches = 1500

train_losses = []
test_losses = []

# adam w learn rate decay
# Pesquisar funcionamento do retorno de optimizers.adam()
opt_init, opt_update, get_params = optimizers.adam(
    lambda t: jnp.select([t < batch_size*(num_batches//3),
                          t < batch_size*(2*num_batches//3),
                          t > batch_size*(2*num_batches//3)],
                         [1e-3, 3e-4, 1e-4]))

opt_state = opt_init(init_params)

for iteration in range(batch_size * num_batches + 1):
  if iteration % batch_size == 0:
    params = get_params(opt_state)

    train_loss = loss(params, (x_train, xt_train))
    train_losses.append(train_loss)
    test_loss = loss(params, (x_test, xt_test))
    test_losses.append(test_loss)

    if iteration % (batch_size * test_every) == 0:
      print(f"iteration={iteration}, train_loss={train_loss:.6f}, test_loss={test_loss:.6f}")

  opt_state = update_derivative(iteration, opt_state, (x_train, xt_train))

params = get_params(opt_state)
# Out:
# iteration=0, train_loss=586.486450, test_loss=586.485840
# iteration=1000, train_loss=0.164191, test_loss=0.164184
# iteration=2000, train_loss=0.127828, test_loss=0.127823
# iteration=3000, train_loss=0.090815, test_loss=0.090811
# iteration=4000, train_loss=0.037934, test_loss=0.037932
# iteration=5000, train_loss=0.027414, test_loss=0.027413
# iteration=6000, train_loss=0.025109, test_loss=0.025108
# iteration=7000, train_loss=0.024191, test_loss=0.024190
# iteration=8000, train_loss=0.023725, test_loss=0.023724
# iteration=9000, train_loss=0.023460, test_loss=0.023459
# iteration=10000, train_loss=0.023298, test_loss=0.023298
# iteration=11000, train_loss=0.023196, test_loss=0.023195
# iteration=12000, train_loss=0.023130, test_loss=0.023129
# iteration=13000, train_loss=0.023086, test_loss=0.023085
# iteration=14000, train_loss=0.023058, test_loss=0.023057
# iteration=15000, train_loss=0.023039, test_loss=0.023038
# iteration=16000, train_loss=0.023026, test_loss=0.023025
# iteration=17000, train_loss=0.023018, test_loss=0.023017
# iteration=18000, train_loss=0.023012, test_loss=0.023012
# iteration=19000, train_loss=0.023009, test_loss=0.023008
# iteration=20000, train_loss=0.023007, test_loss=0.023006
# iteration=21000, train_loss=0.023005, test_loss=0.023004
# iteration=22000, train_loss=0.023002, test_loss=0.023001
# iteration=23000, train_loss=0.023008, test_loss=0.023007
# iteration=24000, train_loss=0.022921, test_loss=0.022921
# iteration=25000, train_loss=0.022874, test_loss=0.022874
# iteration=26000, train_loss=0.022799, test_loss=0.022798
# iteration=27000, train_loss=0.022752, test_loss=0.022751
# iteration=28000, train_loss=0.022707, test_loss=0.022706
# iteration=29000, train_loss=0.022694, test_loss=0.022693
# iteration=30000, train_loss=0.022613, test_loss=0.022613
# iteration=31000, train_loss=0.022649, test_loss=0.022649
# iteration=32000, train_loss=0.022604, test_loss=0.022603
# iteration=33000, train_loss=0.022741, test_loss=0.022740
# iteration=34000, train_loss=0.022428, test_loss=0.022427
# iteration=35000, train_loss=0.022664, test_loss=0.022663
# iteration=36000, train_loss=0.022454, test_loss=0.022453
# iteration=37000, train_loss=0.022637, test_loss=0.022637
# iteration=38000, train_loss=0.022582, test_loss=0.022582
# iteration=39000, train_loss=0.022491, test_loss=0.022490
# iteration=40000, train_loss=0.022147, test_loss=0.022146
# iteration=41000, train_loss=0.022030, test_loss=0.022029
# iteration=42000, train_loss=0.022061, test_loss=0.022060
# iteration=43000, train_loss=0.021993, test_loss=0.021992
# iteration=44000, train_loss=0.022287, test_loss=0.022286
# iteration=45000, train_loss=0.021893, test_loss=0.021893
# iteration=46000, train_loss=0.022038, test_loss=0.022037
# iteration=47000, train_loss=0.022116, test_loss=0.022115
# iteration=48000, train_loss=0.022580, test_loss=0.022580
# iteration=49000, train_loss=0.022081, test_loss=0.022080
# iteration=50000, train_loss=0.022059, test_loss=0.022058
# iteration=51000, train_loss=0.021280, test_loss=0.021279
# iteration=52000, train_loss=0.020684, test_loss=0.020683
# iteration=53000, train_loss=0.020247, test_loss=0.020246
# iteration=54000, train_loss=0.019963, test_loss=0.019962
# iteration=55000, train_loss=0.020729, test_loss=0.020728
# iteration=56000, train_loss=0.019464, test_loss=0.019463
# iteration=57000, train_loss=0.019225, test_loss=0.019224
# iteration=58000, train_loss=0.019042, test_loss=0.019041
# iteration=59000, train_loss=0.018832, test_loss=0.018831
# iteration=60000, train_loss=0.018619, test_loss=0.018618
# iteration=61000, train_loss=0.019814, test_loss=0.019813
# iteration=62000, train_loss=0.018192, test_loss=0.018191
# iteration=63000, train_loss=0.018269, test_loss=0.018268
# iteration=64000, train_loss=0.017908, test_loss=0.017907
# iteration=65000, train_loss=0.018041, test_loss=0.018040
# iteration=66000, train_loss=0.017605, test_loss=0.017605
# iteration=67000, train_loss=0.018328, test_loss=0.018327
# iteration=68000, train_loss=0.019728, test_loss=0.019728
# iteration=69000, train_loss=0.019082, test_loss=0.019082
# iteration=70000, train_loss=0.017117, test_loss=0.017116
# iteration=71000, train_loss=0.019008, test_loss=0.019007
# iteration=72000, train_loss=0.016816, test_loss=0.016816
# iteration=73000, train_loss=0.018002, test_loss=0.018002
# iteration=74000, train_loss=0.021041, test_loss=0.021040
# iteration=75000, train_loss=0.016360, test_loss=0.016359
# iteration=76000, train_loss=0.016753, test_loss=0.016753
# iteration=77000, train_loss=0.016958, test_loss=0.016957
# iteration=78000, train_loss=0.016489, test_loss=0.016488
# iteration=79000, train_loss=0.016724, test_loss=0.016723
# iteration=80000, train_loss=0.017563, test_loss=0.017562
# iteration=81000, train_loss=0.016615, test_loss=0.016615
# iteration=82000, train_loss=0.019417, test_loss=0.019417
# iteration=83000, train_loss=0.016785, test_loss=0.016785
# iteration=84000, train_loss=0.016670, test_loss=0.016669
# iteration=85000, train_loss=0.016603, test_loss=0.016602
# iteration=86000, train_loss=0.018560, test_loss=0.018560
# iteration=87000, train_loss=0.016836, test_loss=0.016835
# iteration=88000, train_loss=0.016902, test_loss=0.016902
# iteration=89000, train_loss=0.014775, test_loss=0.014774
# iteration=90000, train_loss=0.014747, test_loss=0.014746
# iteration=91000, train_loss=0.015204, test_loss=0.015204
# iteration=92000, train_loss=0.014470, test_loss=0.014470
# iteration=93000, train_loss=0.014485, test_loss=0.014485
# iteration=94000, train_loss=0.015757, test_loss=0.015756
# iteration=95000, train_loss=0.015288, test_loss=0.015288
# iteration=96000, train_loss=0.015743, test_loss=0.015743
# iteration=97000, train_loss=0.015995, test_loss=0.015994
# iteration=98000, train_loss=0.016683, test_loss=0.016682
# iteration=99000, train_loss=0.015146, test_loss=0.015145
# iteration=100000, train_loss=0.013680, test_loss=0.013680
# iteration=101000, train_loss=0.013376, test_loss=0.013376
# iteration=102000, train_loss=0.013255, test_loss=0.013254
# iteration=103000, train_loss=0.013092, test_loss=0.013092
# iteration=104000, train_loss=0.012879, test_loss=0.012879
# iteration=105000, train_loss=0.012687, test_loss=0.012687
# iteration=106000, train_loss=0.012529, test_loss=0.012529
# iteration=107000, train_loss=0.012477, test_loss=0.012477
# iteration=108000, train_loss=0.012216, test_loss=0.012215
# iteration=109000, train_loss=0.012186, test_loss=0.012186
# iteration=110000, train_loss=0.012337, test_loss=0.012337
# iteration=111000, train_loss=0.011768, test_loss=0.011768
# iteration=112000, train_loss=0.011626, test_loss=0.011626
# iteration=113000, train_loss=0.011478, test_loss=0.011479
# iteration=114000, train_loss=0.011329, test_loss=0.011329
# iteration=115000, train_loss=0.011211, test_loss=0.011210
# iteration=116000, train_loss=0.011073, test_loss=0.011073
# iteration=117000, train_loss=0.010947, test_loss=0.010946
# iteration=118000, train_loss=0.010961, test_loss=0.010961
# iteration=119000, train_loss=0.010689, test_loss=0.010689
# iteration=120000, train_loss=0.010585, test_loss=0.010585
# iteration=121000, train_loss=0.010453, test_loss=0.010453
# iteration=122000, train_loss=0.010335, test_loss=0.010335
# iteration=123000, train_loss=0.010214, test_loss=0.010214
# iteration=124000, train_loss=0.010094, test_loss=0.010094
# iteration=125000, train_loss=0.010110, test_loss=0.010110
# iteration=126000, train_loss=0.009878, test_loss=0.009877
# iteration=127000, train_loss=0.009775, test_loss=0.009774
# iteration=128000, train_loss=0.015014, test_loss=0.015013
# iteration=129000, train_loss=0.010387, test_loss=0.010387
# iteration=130000, train_loss=0.009479, test_loss=0.009479
# iteration=131000, train_loss=0.009408, test_loss=0.009407
# iteration=132000, train_loss=0.009282, test_loss=0.009282
# iteration=133000, train_loss=0.009410, test_loss=0.009410
# iteration=134000, train_loss=0.009099, test_loss=0.009099
# iteration=135000, train_loss=0.009004, test_loss=0.009004
# iteration=136000, train_loss=0.008913, test_loss=0.008913
# iteration=137000, train_loss=0.008840, test_loss=0.008839
# iteration=138000, train_loss=0.013470, test_loss=0.013470
# iteration=139000, train_loss=0.008657, test_loss=0.008656
# iteration=140000, train_loss=0.008572, test_loss=0.008572
# iteration=141000, train_loss=0.008504, test_loss=0.008503
# iteration=142000, train_loss=0.008463, test_loss=0.008463
# iteration=143000, train_loss=0.008333, test_loss=0.008333
# iteration=144000, train_loss=0.008266, test_loss=0.008266
# iteration=145000, train_loss=0.008181, test_loss=0.008181
# iteration=146000, train_loss=0.009952, test_loss=0.009952
# iteration=147000, train_loss=0.008030, test_loss=0.008030
# iteration=148000, train_loss=0.007961, test_loss=0.007960
# iteration=149000, train_loss=0.011230, test_loss=0.011230
# iteration=150000, train_loss=0.008173, test_loss=0.008173
# CPU times: user 8min 30s, sys: 6min 22s, total: 14min 53s
# Wall time: 14min 20s

# %% [markdown]
# ### iv) Plot losses over training

# %%
plt.figure(figsize=(8, 3.5), dpi=120)
plt.plot(train_losses, 'r-', label='Erro de treino')
plt.plot(test_losses, 'c--', label='Erro de teste')
plt.yscale('log')
plt.ylim(None, 200)
plt.title('Erro durante o treinamento')
plt.xlabel("Passos de treinamento") ; plt.ylabel("Erro médio quadrático")
plt.savefig('cen3-erro-h5.png')
plt.legend() ; plt.show()

# %% [markdown]
# ## **Step 7: Make predictions with the model**

# %%
# choose an initial state
x1 = np.array([0.012, 0], dtype=np.float32)
N = 10000
t2 = np.arange(start=0, stop=5, step=50/N, dtype=np.float32)

# %time x1_analytical = jax.device_get(solve_analytical(x1, t2))
# %time x1_model = jax.device_get(solve_lagrangian(learned_lagrangian(params), x1, t=t2))
# Out:
# CPU times: user 1.05 ms, sys: 41 µs, total: 1.09 ms
# Wall time: 1.1 ms
# CPU times: user 3.53 s, sys: 38.9 ms, total: 3.57 s
# Wall time: 3.53 s

# %%
plt.figure(figsize=[14,4], dpi=120)
plt.subplot(1,2,1)
plt.title("Deslocamento calculado pela 2ª lei de Newton")
plt.xlabel("Tempo") ; plt.ylabel("Deslocamento")
plt.plot(t2, x1_analytical[:, 0], 'g-', label=r'deslocamento') ; plt.xlim(-0.1, 5)
plt.subplot(1,2,2)
plt.title("Deslocamento Previsto pela RNL")
plt.xlabel("Tempo") ; plt.ylabel("Deslocamento")
plt.plot(t2, x1_model[:, 0], 'c-', label=r'deslocamento') ; plt.xlim(-0.1, 5)

plt.figure(figsize=[14,4], dpi=120)
plt.subplot(1,2,1)
plt.title("Velocidade calculada pela 2ª lei de Newton")
plt.xlabel("Tempo") ; plt.ylabel("Velocidade")
plt.plot(t2, x1_analytical[:, 1], 'g-', label=r'velocidade') ; plt.xlim(-0.1, 5)
plt.subplot(1,2,2)
plt.title("Velocidade Prevista pela RNL")
plt.xlabel("Tempo") ; plt.ylabel("Velocidade")
plt.plot(t2, x1_model[:, 1], 'c-', label=r'velocidade') ; plt.xlim(-0.1, 5)
# Out:
# (-0.1, 5.0)

# %%
plt.figure(figsize=[14,4], dpi=120)
plt.subplot(1,2,1)
plt.title("Deslocamento Previsto pela RNL")
plt.xlabel("Tempo") ; plt.ylabel("Deslocamento")
plt.plot(t2, x1_model[:, 0], 'g-', label=r'deslocamento') ; plt.xlim(-0.1, 5)
plt.subplot(1,2,2)
plt.title("Velocidade Prevista pela RNL")
plt.xlabel("Tempo") ; plt.ylabel("Velocidade")
plt.plot(t2, x1_model[:, 1], 'c-', label=r'velocidade') ; plt.xlim(-0.1, 5)
plt.savefig('cen3-rln-h5.png')

# %%
difference_of_states = x1_analytical - x1_model

plt.figure(figsize=[10,4], dpi=120)
# plt.title("Diferença entre o deslocamento calculado pela 2ª lei de Newton e o previsto pela RNL")
plt.xlabel("Tempo") ; plt.ylabel("Deslocamento")
plt.plot(t2, difference_of_states[:, 0], 'g-', label=r'deslocamento') ; plt.xlim(-0.1, 5)
plt.savefig('cen3-diff-desl-h5.png')

plt.figure(figsize=[10,4], dpi=120)
# plt.title("Diferença entre a velocidade calculada pela 2ª lei de Newton e a prevista pela RNL")
plt.xlabel("Tempo") ; plt.ylabel("Velocidade")
plt.plot(t2, difference_of_states[:, 1], 'c-', label=r'velocidade') ; plt.xlim(-0.1, 5)
plt.savefig('cen3-diff-vel-h5.png')
